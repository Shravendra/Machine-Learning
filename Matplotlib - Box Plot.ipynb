# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Box Plot - Its give overview or summery of Statical data.
# IQR -  Inter Quartile Range.

x = [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12, 13, 14, 15]
plt.boxplot(x)
plt.show()

# %%
x = [23, 45, 123, 56, 89]
y = [1, 2, 3, 4, 5]
z = [20, 12, 34, 56, 78]
plt.figure(figsize = (20, 10))

plt. subplot(1, 2, 1)
plt.plot(x, y)

plt.subplot(1, 2, 2)
plt.plot(y, z)
plt. show()

# %%
x = [23, 45, 123, 56, 89]
y = [1, 2, 3, 4, 5]
z = [20, 12, 34, 56, 78]
plt.figure(figsize = (20, 10))

plt.subplot(2, 1, 1)
plt.plot(x, y)

plt.subplot(2, 1, 2)
plt.plot(y, z)
plt.show()

# %%
# Out:
#    total_bill   tip smoker  day    time  size  gender
# 0       16.99  1.01     No  Sun  Dinner     2  Female
# 1       10.34  1.66     No  Sun  Dinner     3    Male
# 2       21.01  3.50     No  Sun  Dinner     3    Male
# 3       23.68  3.31     No  Sun  Dinner     2    Male
# 4       24.59  3.61     No  Sun  Dinner     4  Female
